# %% [markdown]
# ## Part A extracting all tweets of MIDAS IIITD from Twitter API and dumping into JSON

# %%
import tweepy
import csv
import json
import json

# %%
# load Twitter API credentials
with open('twitter_credentials.json') as cred_data:
    info = json.load(cred_data)
    consumer_key = info['CONSUMER_KEY']
    consumer_secret = info['CONSUMER_SECRET']
    access_key = info['ACCESS_KEY']
    access_secret = info['ACCESS_SECRET']

# %%
def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method

    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)

    #initialize a list to hold all the tweepy Tweets
    alltweets = []
    
    new_tweets = api.user_timeline(screen_name = screen_name,tweet_mode="extended")

    #save most recent tweets
    alltweets.extend(new_tweets)

    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1

    # keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:  
        # all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,max_id=oldest,tweet_mode="extended")

        # save most recent tweets
        alltweets.extend(new_tweets)

        # update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1

        print("...%s tweets downloaded so far" % (len(alltweets)))

    print("Total tweets downloaded %s" % (len(alltweets)))
    print("Writing tweet objects to JSON please wait...")
    filewrite=[]
    for status in alltweets:
        filewrite.append(status._json)
    
    with open('tweet.json', 'w', encoding='utf8') as file:        
        json.dump(filewrite,file,sort_keys = True,indent = 4)

# %%
get_all_tweets('midasIIITD')
# Out:
# ...40 tweets downloaded so far
# ...60 tweets downloaded so far
# ...80 tweets downloaded so far
# ...100 tweets downloaded so far
# ...120 tweets downloaded so far
# ...140 tweets downloaded so far
# ...160 tweets downloaded so far
# ...180 tweets downloaded so far
# ...200 tweets downloaded so far
# ...220 tweets downloaded so far
# ...240 tweets downloaded so far
# ...260 tweets downloaded so far
# ...280 tweets downloaded so far
# ...300 tweets downloaded so far
# ...320 tweets downloaded so far
# ...334 tweets downloaded so far
# ...334 tweets downloaded so far
# Total tweets downloaded 334
# Writing tweet objects to JSON please wait...

# %% [markdown]
# ## Part B (Loading json file and showing relevant contents only)

# %%
config = json.loads(open('tweet.json').read())

# %%
import pandas as pd

# %%
df=pd.DataFrame(columns=["Text","Date/Time","number of favorites/likes"," number of retweets","Number Of images in tweet"])

# %%
for i in range(len(config)):
    row=[config[i]['full_text'],config[i]['created_at'],config[i]['favorite_count'],config[i]['retweet_count']]
    try:
        # printing all media urls
        for media in config[i]['extended_entities']['media']:
            print(media['media_url'])
        row.append(len(config[i]['extended_entities']['media']))
    except:
        row.append(None)  # if no media is present simply append None
    
    df.loc[i]=row
# Out:
# http://pbs.twimg.com/media/D3e-35KW0AAzQ3E.jpg
# http://pbs.twimg.com/media/D3XGmdMWAAM7bXv.png
# http://pbs.twimg.com/media/D2rXC3KU8AAUXrb.jpg
# http://pbs.twimg.com/media/D2gZD1IVYAE02dU.jpg
# http://pbs.twimg.com/media/D2gZGVwVYAISCDj.jpg
# http://pbs.twimg.com/media/D1grsHnU8AAj4IZ.png
# http://pbs.twimg.com/media/D1dxxHzXgAIeNSE.jpg
# http://pbs.twimg.com/media/D080rrJXgAAWIQC.jpg
# http://pbs.twimg.com/media/D0vpRy0VAAAOf5g.jpg
# http://pbs.twimg.com/media/D0vpS5nUcAc1eNP.jpg
# http://pbs.twimg.com/media/D0vpUHaU4AEoUlc.jpg
# http://pbs.twimg.com/media/D0f6jC9X4AQJsgU.jpg
# http://pbs.twimg.com/media/Dz1LoMRVsAETaa-.jpg
# http://pbs.twimg.com/media/Dz02vCzU8AIGAqp.jpg
# http://pbs.twimg.com/media/Dz02vCyU0AAvSSq.jpg
# http://pbs.twimg.com/media/DzYK_BAUwAA8sGm.jpg
# http://pbs.twimg.com/media/DzToEKZX4AE7rjc.jpg
# http://pbs.twimg.com/media/DzQrO_7WsAUu8Na.jpg
# http://pbs.twimg.com/media/DyoyOA5VsAApBEK.png
# http://pbs.twimg.com/media/DyYCwoTUYAAyze5.jpg
# http://pbs.twimg.com/media/DyYCztxUUAAjzT6.jpg
# http://pbs.twimg.com/media/DyYC2o2V4AAjA1B.jpg
# http://pbs.twimg.com/media/DyYC3ZQV4AADe-r.jpg
# http://pbs.twimg.com/media/DyTaqPmV4AEinpu.jpg
# http://pbs.twimg.com/media/DyLK6QYX4AIR4ah.jpg
# http://pbs.twimg.com/media/DyIkbrMU0AAZIWk.jpg
# http://pbs.twimg.com/media/DyFhSsFUwAEGU7q.jpg
# http://pbs.twimg.com/media/DyDfRcYUYAAl9xP.jpg
# http://pbs.twimg.com/media/DyDfRcXU8AEA0rg.jpg
# http://pbs.twimg.com/media/Dxr-XHqWkAE84QC.jpg
# http://pbs.twimg.com/media/DxcsbwqU0AENeum.jpg
# http://pbs.twimg.com/media/DxcscLyUcAAZI-6.jpg
# http://pbs.twimg.com/media/DxcsbwpUcAAgrnF.jpg
# http://pbs.twimg.com/media/DxccXePUwAATTtE.jpg
# http://pbs.twimg.com/media/DxccWxuUUAA3izr.jpg
# http://pbs.twimg.com/media/DxccXbwUwAAC5GF.jpg
# http://pbs.twimg.com/media/DxccX7GVAAAup9U.jpg
# http://pbs.twimg.com/media/DxNp3HBWkAEGVAw.jpg
# http://pbs.twimg.com/media/DwzdkXlWwAIvX2J.jpg
# http://pbs.twimg.com/media/DwzdkXfWoAM1uoX.jpg
# http://pbs.twimg.com/media/Dv13uFmXcAA6ulV.jpg
# http://pbs.twimg.com/media/DvVVoG0V4AAFgKs.jpg
# http://pbs.twimg.com/media/DuvsDdEUYAAZz2n.jpg
# http://pbs.twimg.com/media/DuojDP6VAAQ8Qkh.jpg
# http://pbs.twimg.com/media/DuojDRTVAAAHn6K.jpg
# http://pbs.twimg.com/media/DuMAbnJU0AApcf6.jpg
# http://pbs.twimg.com/media/DtVz-fzV4AAnTJm.jpg
# http://pbs.twimg.com/media/DtVz-CnU0AMHIly.jpg
# http://pbs.twimg.com/media/Dsf5bykWsAEVJpt.jpg
# http://pbs.twimg.com/media/Dsf5byfWsAA3hmP.jpg
# http://pbs.twimg.com/media/Dsf5byhXcAE0OVH.jpg
# http://pbs.twimg.com/media/DsbzH-MWkAUFhZX.jpg
# http://pbs.twimg.com/media/DrQ0BWOWkAUzIRn.jpg
# http://pbs.twimg.com/media/DrQ0BWNWwAUzJPh.jpg
# http://pbs.twimg.com/media/DrQ0BWTW4AARv52.jpg
# http://pbs.twimg.com/media/DrQ0BWPX4AAXq-y.jpg
# http://pbs.twimg.com/media/DpFT0dZW0AAG5FY.jpg
# http://pbs.twimg.com/media/DmBCG2JWwAA5Yu3.jpg
# http://pbs.twimg.com/media/DlxuCUiX4AAxzqB.jpg
# http://pbs.twimg.com/media/DlRGPMkU8AATQXB.jpg
# http://pbs.twimg.com/media/Dk52J-zXoAIn3tm.jpg
# http://pbs.twimg.com/media/DksxOnsW0AAOqSL.jpg
# http://pbs.twimg.com/media/DkJlHfTW0AA9ZX-.jpg
# http://pbs.twimg.com/media/DkDi4wUUYAE-q2o.jpg
# http://pbs.twimg.com/media/Dj-a-5oXcAAy68A.jpg
# http://pbs.twimg.com/media/Dj7dAUgXcAAxr3U.jpg
# http://pbs.twimg.com/media/DjgwwGVUYAAOv8w.jpg
# http://pbs.twimg.com/media/Di3Ib2rUwAAklmz.jpg

# %%
df
# Out:
#                                                   Text  \
# 0    We request all students whose interview are sc...
# 1    Other queries: "none of the Tweeter Apis give ...
# 2    Other queries: "do we have to make two differe...
# 3    Other queries: "If using Twitter api, it does ...
# 4    Response to some queries asked by students on ...
# 5    RT @kdnuggets: Top 8 #Free Must-Read #Books on...
# 6    @nupur_baghel @PennDATS Congratulation @nupur_...
# 7    We have emailed the task details to all candid...
# 8    RT @rfpvjr: Our NAACL paper on polarization in...
# 9    RT @kdnuggets: Effective Transfer Learning For...
# 10   RT @stanfordnlp: What’s new in @Stanford CS224...
# 11   RT @DeepMindAI: Today we're releasing a large-...
# 12   RT @ylecun: Congratulations Jitendra Malik !\n...
# 13   RT @IIITDelhi: Another chance to take admissio...
# 14   Dear @midasIIITD internship candidates who hav...
# 15   Looking forward to your paper submission to @I...
# 16   RT @ngrams: Reproducibility in multimedia rese...
# 17   Online application for https://t.co/DJFDrQsHZP...
# 18   RT @ACMMM19: A final reminder of the Reproduci...
# 19   RT @isarth23: Thanks for the support and help ...
# 20   Since SemEval-2019 will be held June 6-7, 2019...
# 21   +@aggarwal_kartik.\nCongrats! Wish you many mo...
# 22   RT @aggarwal_kartik: Our work (@midasIIITD ) a...
# 23   Congratulations! @midasIIITD team, @isarth23 @...
# 24   @EEMLcommunity @radamihalcea too many deadline...
# 25   RT @stanfordnlp: CS224N Natural Language Proce...
# 26   RT @ylecun: Learn PyTorch by running on Google...
# 27   Dr. Vineeth N Balasubramanian will present a T...
# 28   RT @ylecun: I am extremely honored to be the r...
# 29   Thanks to all shortlisted candidates for submi...
# ..                                                 ...
# 304  RT @TensorFlow: TensorFlow 1.10.0 has been rel...
# 305  @midasIIITD is looking for motivated IIITD MTe...
# 306  @IIITDelhi @ponguru @RatnRajiv The results of ...
# 307  RT @IIITDelhi: @midasIIITD has secured rank 1 ...
# 308  RT @kdnuggets: Comparison of Top 6 Python NLP ...
# 309  Check more details of the 20th IEEE Internatio...
# 310  MR2AMC@ISM 2018 will be organized by @RatnRaji...
# 311  Our workshop proposal named, "MR2AMC: Multimod...
# 312  @NUSComputing Congratulations Abdelhak and Pro...
# 313  RT @goodfellow_ian: One of the most anticipate...
# 314     @the_dhumketu Great to have you in @midasIIITD
# 315  Congratulation @soujanyaporia for being appoin...
# 316  @IIITDelhi @the_dhumketu Thanks team @midasIII...
# 317  RT @IIITDelhi: Congratulations @midasIIITD int...
# 318  RT @learning_pt: Profile of the 5 Indian under...
# 319  Have a look at the list of accepted papers in ...
# 320  RT @goodfellow_ian: https://t.co/hYiWI7ntyk Te...
# 321  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ...
# 322  RT @ylecun: Jitendra Malik, who directs FAIR-M...
# 323  RT @kdnuggets: .@Bloomberg launches free cours...
# 324  RT @TechAtBloomberg: Missed #PyLondinium18? Wa...
# 325  RT @IIITDelhi: We are delighted to announce th...
# 326  Get ready for the annual technical fest of @II...
# 327  Congratulations Dr. @RatnRajiv and team @midas...
# 328  Congratulations MIDAS @midasIIITD intern Prakh...
# 329    MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm
# 330  It feels great to be the part of @IIITDelhi. h...
# 331  Thank you, @toonzratn for designing the logo o...
# 332  We are on Facebook too. Like our page to get o...
# 333  MIDAS is a group of researchers at IIIT-Delhi ...
#
#                           Date/Time number of favorites/likes  \
# 0    Sun Apr 07 11:43:24 +0000 2019                         0
# 1    Sun Apr 07 06:55:19 +0000 2019                         3
# 2    Sun Apr 07 06:53:38 +0000 2019                         4
# 3    Sun Apr 07 05:32:27 +0000 2019                         4
# 4    Sun Apr 07 05:29:40 +0000 2019                         6
# 5    Sat Apr 06 17:11:29 +0000 2019                         0
# 6    Sat Apr 06 16:43:27 +0000 2019                        15
# 7    Fri Apr 05 16:08:37 +0000 2019                        10
# 8    Fri Apr 05 04:05:11 +0000 2019                         0
# 9    Fri Apr 05 04:04:43 +0000 2019                         0
# 10   Wed Apr 03 18:31:53 +0000 2019                         0
# 11   Wed Apr 03 17:04:32 +0000 2019                         0
# 12   Wed Apr 03 09:03:40 +0000 2019                         0
# 13   Wed Apr 03 07:46:02 +0000 2019                         0
# 14   Tue Apr 02 04:20:13 +0000 2019                         8
# 15   Tue Apr 02 02:44:54 +0000 2019                         5
# 16   Tue Apr 02 02:35:44 +0000 2019                         0
# 17   Mon Apr 01 06:53:08 +0000 2019                         7
# 18   Sun Mar 31 10:21:24 +0000 2019                         0
# 19   Fri Mar 29 19:43:24 +0000 2019                         0
# 20   Fri Mar 29 17:16:40 +0000 2019                         9
# 21   Fri Mar 29 17:04:30 +0000 2019                         2
# 22   Fri Mar 29 17:03:29 +0000 2019                         0
# 23   Fri Mar 29 17:02:24 +0000 2019                         9
# 24   Fri Mar 29 05:35:22 +0000 2019                         0
# 25   Thu Mar 28 16:55:01 +0000 2019                         0
# 26   Thu Mar 28 16:54:37 +0000 2019                         0
# 27   Wed Mar 27 16:09:09 +0000 2019                         4
# 28   Wed Mar 27 11:53:40 +0000 2019                         0
# 29   Tue Mar 26 18:12:27 +0000 2019                         5
# ..                              ...                       ...
# 304  Thu Aug 09 05:59:57 +0000 2018                         0
# 305  Wed Aug 08 11:30:56 +0000 2018                         2
# 306  Wed Aug 08 05:53:48 +0000 2018                         3
# 307  Wed Aug 08 05:45:58 +0000 2018                         0
# 308  Tue Aug 07 07:16:33 +0000 2018                         0
# 309  Tue Aug 07 02:05:12 +0000 2018                         1
# 310  Tue Aug 07 01:58:49 +0000 2018                         1
# 311  Tue Aug 07 01:50:33 +0000 2018                         1
# 312  Mon Aug 06 17:48:23 +0000 2018                         0
# 313  Mon Aug 06 17:46:59 +0000 2018                         0
# 314  Mon Aug 06 06:06:47 +0000 2018                         0
# 315  Fri Aug 03 05:56:33 +0000 2018                         6
# 316  Wed Aug 01 11:47:15 +0000 2018                         5
# 317  Wed Aug 01 11:20:07 +0000 2018                         0
# 318  Wed Aug 01 05:06:47 +0000 2018                         0
# 319  Tue Jul 31 12:11:52 +0000 2018                         1
# 320  Tue Jul 31 02:06:26 +0000 2018                         0
# 321  Mon Jul 30 07:30:51 +0000 2018                         0
# 322  Sat Jul 28 11:07:11 +0000 2018                         0
# 323  Sat Jul 28 06:14:09 +0000 2018                         0
# 324  Sat Jul 28 06:13:48 +0000 2018                         0
# 325  Sat Jul 28 04:08:21 +0000 2018                         0
# 326  Fri Jul 27 06:46:44 +0000 2018                         3
# 327  Fri Jul 27 04:07:31 +0000 2018                         8
# 328  Wed Jul 25 05:14:35 +0000 2018                         5
# 329  Tue Jul 24 10:33:23 +0000 2018                         2
# 330  Tue Jul 24 10:12:34 +0000 2018                         2
# 331  Tue Jul 24 09:46:26 +0000 2018                         4
# 332  Mon Jul 23 16:25:05 +0000 2018                         3
# 333  Mon Jul 23 12:53:15 +0000 2018                         7
#
#      number of retweets Number Of images in tweet
# 0                     1                      None
# 1                     2                      None
# 2                     1                      None
# 3                     1                      None
# 4                     1                      None
# 5                     2                      None
# 6                     3                         1
# 7                     1                      None
# 8                    16                      None
# 9                    11                         1
# 10                   59                      None
# 11                  848                      None
# 12                   16                      None
# 13                    4                      None
# 14                    1                      None
# 15                    1                      None
# 16                    7                      None
# 17                    2                      None
# 18                   10                      None
# 19                    2                      None
# 20                    1                      None
# 21                    0                      None
# 22                    1                      None
# 23                    1                      None
# 24                    0                      None
# 25                  715                      None
# 26                  157                      None
# 27                    1                         1
# 28                 1546                      None
# 29                    1                      None
# ..                  ...                       ...
# 304                 265                      None
# 305                   1                      None
# 306                   1                         1
# 307                   1                      None
# 308                  40                         1
# 309                   1                      None
# 310                   1                      None
# 311                   1                      None
# 312                   0                      None
# 313                 103                         1
# 314                   0                      None
# 315                   1                      None
# 316                   1                         1
# 317                   4                      None
# 318                   4                      None
# 319                   0                      None
# 320                 264                      None
# 321                   2                      None
# 322                  57                      None
# 323                 105                      None
# 324                   7                      None
# 325                   6                      None
# 326                   2                      None
# 327                   2                      None
# 328                   1                      None
# 329                   1                      None
# 330                   1                      None
# 331                   1                         1
# 332                   1                      None
# 333                   4                      None
#
# [334 rows x 5 columns]
